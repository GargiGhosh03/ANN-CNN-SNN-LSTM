# %%
import numpy as np

import seaborn as sns

import matplotlib.pyplot as plt

import pandas as pd

import tensorflow as tf

import os

import scipy

import tensorflow.compat.v2 as tf


from tensorflow.keras.layers import Dense, Activation, Flatten, concatenate, Input, Dropout, LSTM, Bidirectional,BatchNormalization,PReLU,ReLU,Reshape

from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix, classification_report

from tensorflow.keras.models import Sequential, Model, load_model

from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from tensorflow.keras.layers import Conv1D,Conv2D,Add

from tensorflow.keras.layers import MaxPool1D, MaxPooling2D

from sklearn import metrics

from sklearn.preprocessing import LabelEncoder

from tensorflow import keras as k

# %%
mrc_data=pd.read_csv('/kaggle/input/eeg-brainwave-dataset-feeling-emotions/emotions.csv')

print(mrc_data)
# Out:
#       # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  \
# 0          4.620      30.3    -356.0     15.60      26.3       1.070
# 1         28.800      33.1      32.0     25.80      22.8       6.550
# 2          8.900      29.4    -416.0     16.70      23.7      79.900
# 3         14.900      31.6    -143.0     19.80      24.3      -0.584
# 4         28.300      31.3      45.2     27.30      24.5      34.800
# ...          ...       ...       ...       ...       ...         ...
# 2127      32.400      32.2      32.2     30.80      23.4       1.640
# 2128      16.300      31.3    -284.0     14.30      23.9       4.200
# 2129      -0.547      28.3    -259.0     15.80      26.7       9.080
# 2130      16.800      19.9    -288.0      8.34      26.0       2.460
# 2131      27.000      32.0      31.8     25.00      28.9       4.990
#
#       mean_d_1_a  mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  \
# 0          0.411     -15.700       2.060        3.15  ...      23.50
# 1          1.680       2.880       3.830       -4.82  ...     -23.30
# 2          3.360      90.200      89.900        2.03  ...     462.00
# 3         -0.284       8.820       2.300       -1.97  ...     299.00
# 4         -5.790       3.060      41.400        5.52  ...      12.00
# ...          ...         ...         ...         ...  ...        ...
# 2127      -2.030       0.647      -0.121       -1.10  ...     -21.70
# 2128       1.090       4.460       4.720        6.63  ...     594.00
# 2129       6.900      12.700       2.030        4.64  ...     370.00
# 2130       1.580     -16.000       1.690        4.74  ...     124.00
# 2131       1.950       6.210       3.490       -3.51  ...       1.95
#
#       fft_742_b  fft_743_b  fft_744_b  fft_745_b  fft_746_b  fft_747_b  \
# 0        20.300     20.300      23.50     -215.0     280.00    -162.00
# 1       -21.800    -21.800     -23.30      182.0       2.57     -31.60
# 2      -233.000   -233.000     462.00     -267.0     281.00    -148.00
# 3      -243.000   -243.000     299.00      132.0     -12.40       9.53
# 4        38.100     38.100      12.00      119.0     -17.60      23.90
# ...         ...        ...        ...        ...        ...        ...
# 2127      0.218      0.218     -21.70       95.2     -19.90      47.20
# 2128   -324.000   -324.000     594.00      -35.5     142.00     -59.80
# 2129   -160.000   -160.000     370.00      408.0    -169.00     -10.50
# 2130    -27.600    -27.600     124.00     -656.0     552.00    -271.00
# 2131      1.810      1.810       1.95      110.0      -6.71      22.80
#
#       fft_748_b  fft_749_b     label
# 0       -162.00     280.00  NEGATIVE
# 1        -31.60       2.57   NEUTRAL
# 2       -148.00     281.00  POSITIVE
# 3          9.53     -12.40  POSITIVE
# 4         23.90     -17.60   NEUTRAL
# ...         ...        ...       ...
# 2127      47.20     -19.90   NEUTRAL
# 2128     -59.80     142.00  POSITIVE
# 2129     -10.50    -169.00  NEGATIVE
# 2130    -271.00     552.00  NEGATIVE
# 2131      22.80      -6.71   NEUTRAL
#
# [2132 rows x 2549 columns]

# %%
mrc_data.head(3)
# Out:
#    # mean_0_a  mean_1_a  mean_2_a  mean_3_a  mean_4_a  mean_d_0_a  mean_d_1_a  \
# 0        4.62      30.3    -356.0      15.6      26.3        1.07       0.411
# 1       28.80      33.1      32.0      25.8      22.8        6.55       1.680
# 2        8.90      29.4    -416.0      16.7      23.7       79.90       3.360
#
#    mean_d_2_a  mean_d_3_a  mean_d_4_a  ...  fft_741_b  fft_742_b  fft_743_b  \
# 0      -15.70        2.06        3.15  ...       23.5       20.3       20.3
# 1        2.88        3.83       -4.82  ...      -23.3      -21.8      -21.8
# 2       90.20       89.90        2.03  ...      462.0     -233.0     -233.0
#
#    fft_744_b  fft_745_b  fft_746_b  fft_747_b  fft_748_b  fft_749_b     label
# 0       23.5     -215.0     280.00     -162.0     -162.0     280.00  NEGATIVE
# 1      -23.3      182.0       2.57      -31.6      -31.6       2.57   NEUTRAL
# 2      462.0     -267.0     281.00     -148.0     -148.0     281.00  POSITIVE
#
# [3 rows x 2549 columns]

# %%
smp_data=mrc_data.loc[:,'fft_0_a':'fft_749_a']

# %%
smp_data.head(3)
# Out:
#    fft_0_a  fft_1_a  fft_2_a  fft_3_a  fft_4_a  fft_5_a  fft_6_a  fft_7_a  \
# 0   -520.0    398.0   -201.0   -201.0    398.0    -52.2    121.0    -64.0
# 1     66.2     -4.3     43.6     43.6     -4.3     66.0    -29.0     73.3
# 2    -90.8    204.0    -77.1    -77.1    204.0   -488.0    415.0   -187.0
#
#    fft_8_a  fft_9_a  ...  fft_740_a  fft_741_a  fft_742_a  fft_743_a  \
# 0    -64.0    121.0  ...      179.0       26.4      -12.9      -12.9
# 1     73.3    -29.0  ...      184.0       17.0      -18.9      -18.9
# 2   -187.0    415.0  ...     -796.0      631.0     -261.0     -261.0
#
#    fft_744_a  fft_745_a  fft_746_a  fft_747_a  fft_748_a  fft_749_a
# 0       26.4     -474.0      442.0    -222.00    -222.00      442.0
# 1       17.0      189.0      -19.6      -8.37      -8.37      -19.6
# 2      631.0      -86.4      176.0    -100.00    -100.00      176.0
#
# [3 rows x 750 columns]

# %%
mrc_data['label'].value_counts()
# Out:
# label
# NEUTRAL     716
# NEGATIVE    708
# POSITIVE    708
# Name: count, dtype: int64

# %%
le=LabelEncoder()
mrc_data['label']=le.fit_transform(mrc_data['label'])

# %%
sample = mrc_data.loc[0, 'fft_0_b':'fft_749_b']
plt.figure(figsize=(18, 8))
plt.plot(range(len(sample)), sample)
plt.title("EEG Time-Series Data")
plt.xlabel("Time")
plt.ylabel("Amplitude")
plt.show()

# %%
y=mrc_data.pop('label')

X=mrc_data

X_train,X_test,y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=55)

X_train=np.array(X_train).reshape((X_train.shape[0],X_train.shape[1],1))

X_test=np.array(X_test).reshape((X_test.shape[0],X_test.shape[1],1))

y_train=pd.get_dummies(y_train)

y_test=pd.get_dummies(y_test)

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout,Activation,LSTM,ReLU,Reshape,Bidirectional,BatchNormalization,Input,concatenate,PReLU

inps=tf.keras.Input(shape=(X_train.shape[1],1))

gru=tf.keras.layers.GRU(256,return_sequences=True)(inps)

flt=Flatten()(gru)

out=Dense(3, activation='softmax')(flt)

model=tf.keras.Model(inps,out)

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 2548, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 2548, 256)      │       198,912 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 652288)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │     1,956,867 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,155,779 (8.22 MB)
#  Trainable params: 2,155,779 (8.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow import keras

def train_model(model,X_train,  y_train,X_test,y_test, save_to, epoch=2):

        kadam=keras.optimizers.Adam(learning_rate=0.001)

        es=EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)

        mc=ModelCheckpoint(save_to+'_best_model.keras', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)

        LRS_Schule=tf.keras.callbacks.LearningRateScheduler(lambda epoch:0.001*np.exp(-epoch/10.))


        model.compile(optimizer=kadam,loss=['categorical_crossentropy'],metrics=['accuracy'])

        his=model.fit(X_train,y_train,batch_size=32,epochs=epoch,validation_data=(X_test,y_test),callbacks=[es,mc,LRS_Schule])

        saved_model=load_model(save_to+'_best_model.keras')

        return model,his

# %%
model,his=train_model(model,X_train, y_train, X_test, y_test, save_to ='./', epoch=40)
# Out:
# Epoch 1/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.7306 - loss: 30.8189
# Epoch 1: val_accuracy improved from -inf to 0.88993, saving model to ./_best_model.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - accuracy: 0.7321 - loss: 30.6534 - val_accuracy: 0.8899 - val_loss: 19.7273 - learning_rate: 0.0010
# Epoch 2/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8988 - loss: 10.2253
# Epoch 2: val_accuracy improved from 0.88993 to 0.95082, saving model to ./_best_model.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.8991 - loss: 10.1632 - val_accuracy: 0.9508 - val_loss: 2.2227 - learning_rate: 9.0484e-04
# Epoch 3/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9572 - loss: 1.8672
# Epoch 3: val_accuracy did not improve from 0.95082
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9571 - loss: 1.8661 - val_accuracy: 0.9461 - val_loss: 3.8919 - learning_rate: 8.1873e-04
# Epoch 4/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9763 - loss: 1.0511
# Epoch 4: val_accuracy improved from 0.95082 to 0.96956, saving model to ./_best_model.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.9764 - loss: 1.0465 - val_accuracy: 0.9696 - val_loss: 1.8588 - learning_rate: 7.4082e-04
# Epoch 5/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9952 - loss: 0.1380
# Epoch 5: val_accuracy improved from 0.96956 to 0.97190, saving model to ./_best_model.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.9950 - loss: 0.1445 - val_accuracy: 0.9719 - val_loss: 1.8559 - learning_rate: 6.7032e-04
# Epoch 6/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9769 - loss: 0.8769
# Epoch 6: val_accuracy did not improve from 0.97190
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9770 - loss: 0.8718 - val_accuracy: 0.9602 - val_loss: 3.0501 - learning_rate: 6.0653e-04
# Epoch 7/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9952 - loss: 0.0672
# Epoch 7: val_accuracy did not improve from 0.97190
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 0.9952 - loss: 0.0669 - val_accuracy: 0.9719 - val_loss: 1.4202 - learning_rate: 5.4881e-04
# Epoch 8/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9998 - loss: 1.2108e-04
# Epoch 8: val_accuracy improved from 0.97190 to 0.97892, saving model to ./_best_model.keras
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 131ms/step - accuracy: 0.9998 - loss: 1.2689e-04 - val_accuracy: 0.9789 - val_loss: 1.5967 - learning_rate: 4.9659e-04
# Epoch 9/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9976 - loss: 0.0661
# Epoch 9: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9976 - loss: 0.0656 - val_accuracy: 0.9696 - val_loss: 1.6417 - learning_rate: 4.4933e-04
# Epoch 10/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9976 - loss: 0.0110
# Epoch 10: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9976 - loss: 0.0113 - val_accuracy: 0.9719 - val_loss: 1.5323 - learning_rate: 4.0657e-04
# Epoch 11/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9991 - loss: 0.0137
# Epoch 11: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9991 - loss: 0.0138 - val_accuracy: 0.9766 - val_loss: 1.5957 - learning_rate: 3.6788e-04
# Epoch 12/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9975 - loss: 0.0328
# Epoch 12: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.9975 - loss: 0.0333 - val_accuracy: 0.9602 - val_loss: 2.0714 - learning_rate: 3.3287e-04
# Epoch 13/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 13: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 1.0000 - loss: 0.0000e+00 - val_accuracy: 0.9742 - val_loss: 1.4443 - learning_rate: 3.0119e-04
# Epoch 14/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 3.3206e-10
# Epoch 14: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 1.0000 - loss: 3.4128e-10 - val_accuracy: 0.9742 - val_loss: 1.4452 - learning_rate: 2.7253e-04
# Epoch 15/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 1.0000 - loss: 5.3686e-10
# Epoch 15: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 1.0000 - loss: 5.4236e-10 - val_accuracy: 0.9742 - val_loss: 1.4452 - learning_rate: 2.4660e-04
# Epoch 16/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 1.4962e-10
# Epoch 16: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 1.0000 - loss: 1.6215e-10 - val_accuracy: 0.9742 - val_loss: 1.4452 - learning_rate: 2.2313e-04
# Epoch 17/40
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 1.0000 - loss: 3.3206e-10
# Epoch 17: val_accuracy did not improve from 0.97892
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 7s 129ms/step - accuracy: 1.0000 - loss: 3.4128e-10 - val_accuracy: 0.9742 - val_loss: 1.4452 - learning_rate: 2.0190e-04
# Epoch 17: early stopping

# %%
plt.plot(his.history['accuracy'])

plt.plot(his.history['val_accuracy'])

plt.title('Model Accuracy',fontsize=20,fontweight='bold',color='green')

plt.ylabel('accuracy')

plt.xlabel('epoch')

plt.legend(['train'],'[test]',loc='upper left')

plt.show()
# Out:
# /tmp/ipykernel_30/2680004345.py:11: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   plt.legend(['train'],'[test]',loc='upper left')

# %%
model_acc=model.evaluate(X_test,y_test,verbose=0)[1]

print("Test Accuracy: {:.4f} %".format(model_acc*100))
# Out:
# Test Accuracy: 97.4239 %

# %%
y_pred = np.array(list(map(lambda x: np.argmax(x), model.predict(X_test))))

y_test = y_test.idxmax(axis=1)

cm = confusion_matrix(y_test, y_pred)

cr = classification_report(y_test, y_pred)

plt.figure(figsize=(10, 10))

sns.heatmap(cm, annot=True, vmin=0, fmt='g', cbar=False, cmap='Blues')

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.title("Confusion Matrix",fontsize=20)

plt.show()

print("Report of Classification \n", cr)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step
# Report of Classification
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       141
#            1       1.00      0.98      0.99       149
#            2       0.96      0.96      0.96       137
#
#     accuracy                           0.97       427
#    macro avg       0.97      0.97      0.97       427
# weighted avg       0.97      0.97      0.97       427
